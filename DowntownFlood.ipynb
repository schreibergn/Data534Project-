# %%
import pandas as pd

# %%
df = pd.read_csv('History_Flood_Closures_with_Conditions.csv')
df.head()
# Out:
#    OBJECTID IS_DRILL                STREET REASON    TYPE         SOURCE  \
# 0         1      NaN  SEPTIMA P CLARK PKWY  FLOOD  CLOSED  Charleston PD
# 1         2       No            HAGOOD AVE  FLOOD  CLOSED  Charleston PD
# 2         3      NaN            COUNCIL ST  FLOOD  CLOSED  Charleston PD
# 3         4      NaN           BEAUFAIN ST  FLOOD  CLOSED  Charleston PD
# 4         5      NaN          FISHBURNE ST  FLOOD  CLOSED  Charleston PD
#
#   RoadClosureDate          RoadClosureEnd INCIDENT_DATE  YEAR  ...  \
# 0             NaN  2017/09/12 03:45:00+00           NaN   NaN  ...
# 1             NaN  2019/12/24 06:00:00+00           NaN   NaN  ...
# 2             NaN  2022/09/30 17:33:14+00           NaN   NaN  ...
# 3             NaN  2022/10/06 20:00:00+00           NaN   NaN  ...
# 4             NaN  2019/02/20 10:00:00+00           NaN   NaN  ...
#
#    MoonPhaseDesc DailyPrecipitation_Downtown DailyPrecipitationCat_Downtown  \
# ...
